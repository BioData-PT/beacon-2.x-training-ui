# %% [markdown]
# # Testing PyMongo

# %%
import pymongo
import json
from bson import json_util

# %%
# to display the response
def parse_json(data):
    return json.loads(json_util.dumps(data))

# %%
# connecting to mongo
connect_string = 'mongodb://root:example@localhost'
my_client = pymongo.MongoClient(connect_string)

# %%
# specifying db
dbname = my_client['beacon']

# %% [markdown]
# Getting one document

# %%
document = dbname["individuals"].find_one()

# %%
parse_json(document)
# Out:
# {'_id': {'$oid': '61f955f4d3ec3cdfd2b4a458'},
#  'ethnicity': {'id': 'NCIT:C41260', 'label': 'Asian or Asian British'},
#  'geographicOrigin': {'id': 'GAZ:00002640', 'label': 'Wales'},
#  'id': 'HG00099',
#  'interventionsOrProcedures': [{'procedureCode': {'id': 'OPCS4:T89.4',
#     'label': 'OPCS(v4-0.0):Cannulation of lymphatic duct'}}],
#  'measures': [{'assayCode': {'id': 'LOINC:35925-4', 'label': 'BMI'},
#    'date': '2021-09-24',
#    'measurementValue': {'units': {'id': 'NCIT:C49671',
#      'label': 'Kilogram per Square Meter'},
#     'value': 22.35976255}},
#   {'assayCode': {'id': 'LOINC:3141-9', 'label': 'Weight'},
#    'date': '2021-09-24',
#    'measurementValue': {'units': {'id': 'NCIT:C28252', 'label': 'Kilogram'},
#     'value': 64.4364}},
#   {'assayCode': {'id': 'LOINC:8308-9', 'label': 'Height-standing'},
#    'date': '2021-09-24',
#    'measurementValue': {'units': {'id': 'NCIT:C49668', 'label': 'Centimeter'},
#     'value': 169.7587}}],
#  'sex': {'id': 'NCIT:C16576', 'label': 'female'}}

# %% [markdown]
# Getting 5 documents

# %%
for r in dbname["individuals"].find().limit(5):
    print(r)
# Out:
# {'_id': ObjectId('61f955f4d3ec3cdfd2b4a458'), 'ethnicity': {'id': 'NCIT:C41260', 'label': 'Asian or Asian British'}, 'geographicOrigin': {'id': 'GAZ:00002640', 'label': 'Wales'}, 'id': 'HG00099', 'interventionsOrProcedures': [{'procedureCode': {'id': 'OPCS4:T89.4', 'label': 'OPCS(v4-0.0):Cannulation of lymphatic duct'}}], 'measures': [{'assayCode': {'id': 'LOINC:35925-4', 'label': 'BMI'}, 'date': '2021-09-24', 'measurementValue': {'units': {'id': 'NCIT:C49671', 'label': 'Kilogram per Square Meter'}, 'value': 22.35976255}}, {'assayCode': {'id': 'LOINC:3141-9', 'label': 'Weight'}, 'date': '2021-09-24', 'measurementValue': {'units': {'id': 'NCIT:C28252', 'label': 'Kilogram'}, 'value': 64.4364}}, {'assayCode': {'id': 'LOINC:8308-9', 'label': 'Height-standing'}, 'date': '2021-09-24', 'measurementValue': {'units': {'id': 'NCIT:C49668', 'label': 'Centimeter'}, 'value': 169.7587}}], 'sex': {'id': 'NCIT:C16576', 'label': 'female'}}
# {'_id': ObjectId('61f955f4d3ec3cdfd2b4a459'), 'ethnicity': {'id': 'NCIT:C42331', 'label': 'African'}, 'id': 'HG00096', 'interventionsOrProcedures': [{'procedureCode': {'id': 'OPCS4:L46.3', 'label': 'OPCS(v4-0.0):Ligation of visceral branch of abdominal aorta NEC'}}], 'measures': [{'assayCode': {'id': 'LOINC:35925-4', 'label': 'BMI'}, 'date': '2021-09-24', 'measurementValue': {'units': {'id': 'NCIT:C49671', 'label': 'Kilogram per Square Meter'}, 'value': 26.63838307}}, {'assayCode': {'id': 'LOINC:3141-9', 'label': 'Weight'}, 'date': '2021-09-24', 'measurementValue': {'units': {'id': 'NCIT:C28252', 'label': 'Kilogram'}, 'value': 85.6358}}, {'assayCode': {'id': 'LOINC:8308-9', 'label': 'Height-standing'}, 'date': '2021-09-24', 'measurementValue': {'units': {'id': 'NCIT:C49668', 'label': 'Centimeter'}, 'value': 179.2973}}], 'sex': {'id': 'NCIT:C20197', 'label': 'male'}}
# {'_id': ObjectId('61f955f4d3ec3cdfd2b4a45a'), 'ethnicity': {'id': 'NCIT:C41261', 'label': 'British'}, 'geographicOrigin': {'id': 'GAZ:00002641', 'label': 'England'}, 'id': 'HG00097', 'interventionsOrProcedures': [{'procedureCode': {'id': 'OPCS4:K06.1', 'label': 'OPCS(v4-0.0):Repositioning of transposed great arteries'}}], 'measures': [{'assayCode': {'id': 'LOINC:35925-4', 'label': 'BMI'}, 'date': '2021-09-24', 'measurementValue': {'units': {'id': 'NCIT:C49671', 'label': 'Kilogram per Square Meter'}, 'value': 25.62278441}}, {'assayCode': {'id': 'LOINC:3141-9', 'label': 'Weight'}, 'date': '2021-09-24', 'measurementValue': {'units': {'id': 'NCIT:C28252', 'label': 'Kilogram'}, 'value': 64.5722}}, {'assayCode': {'id': 'LOINC:8308-9', 'label': 'Height-standing'}, 'date': '2021-09-24', 'measurementValue': {'units': {'id': 'NCIT:C49668', 'label': 'Centimeter'}, 'value': 158.7485}}], 'sex': {'id': 'NCIT:C16576', 'label': 'female'}}
# {'_id': ObjectId('61f955f4d3ec3cdfd2b4a45b'), 'geographicOrigin': {'id': 'GAZ:00002638', 'label': 'Northern Ireland'}, 'id': 'HG00102', 'interventionsOrProcedures': [{'procedureCode': {'id': 'OPCS4:E55.9', 'label': 'OPCS(v4-0.0):Unspecified open extirpation of lesion of lung'}}], 'measures': [{'assayCode': {'id': 'LOINC:35925-4', 'label': 'BMI'}, 'date': '2021-09-24', 'measurementValue': {'units': {'id': 'NCIT:C49671', 'label': 'Kilogram per Square Meter'}, 'value': 30.94363585}}, {'assayCode': {'id': 'LOINC:3141-9', 'label': 'Weight'}, 'date': '2021-09-24', 'measurementValue': {'units': {'id': 'NCIT:C28252', 'label': 'Kilogram'}, 'value': 81.8213}}, {'assayCode': {'id': 'LOINC:8308-9', 'label': 'Height-standing'}, 'date': '2021-09-24', 'measurementValue': {'units': {'id': 'NCIT:C49668', 'label': 'Centimeter'}, 'value': 162.6101}}], 'sex': {'id': 'NCIT:C16576', 'label': 'female'}}
# {'_id': ObjectId('61f955f4d3ec3cdfd2b4a45c'), 'ethnicity': {'id': 'NCIT:C16352', 'label': 'Black or Black British'}, 'geographicOrigin': {'id': 'GAZ:00002641', 'label': 'England'}, 'id': 'HG00106', 'interventionsOrProcedures': [{'procedureCode': {'id': 'OPCS4:C01.8', 'label': 'OPCS(v4-0.0):Other specified excision of eye'}}], 'measures': [{'assayCode': {'id': 'LOINC:35925-4', 'label': 'BMI'}, 'date': '2021-09-24', 'measurementValue': {'units': {'id': 'NCIT:C49671', 'label': 'Kilogram per Square Meter'}, 'value': 28.17336761}}, {'assayCode': {'id': 'LOINC:3141-9', 'label': 'Weight'}, 'date': '2021-09-24', 'measurementValue': {'units': {'id': 'NCIT:C28252', 'label': 'Kilogram'}, 'value': 94.9065}}, {'assayCode': {'id': 'LOINC:8308-9', 'label': 'Height-standing'}, 'date': '2021-09-24', 'measurementValue': {'units': {'id': 'NCIT:C49668', 'label': 'Centimeter'}, 'value': 183.5391}}], 'sex': {'id': 'NCIT:C16576', 'label': 'female'}}

# %% [markdown]
# Searching one specific variant, showing it and counting response

# %%
response = dbname["genomicVariations"].find({"position.start": 16050855, "referenceBases": "G", "alternateBases": "T"})

# %%
for r in response:
    print(r)
# Out:
# {'_id': ObjectId('61f955fe7840ef8e91634f06'), 'variantType': 'SNP', 'position': {'end': [16050856], 'assemblyId': 'hs37', 'refseqId': '22', 'start': [16050855]}, 'variantInternalId': 'chr22_16050856_G_T', 'alternateBases': 'T', 'molecularAttributes': {'annotationImpact': ['MODIFIER'], 'molecularEffects': [{'id': 'ENSGLOSSARY:0000174', 'label': 'intergenic_region'}], 'geneIds': ['CHR_START-DUXAP8'], 'aminoacidChanges': ['.']}, 'referenceBases': 'G', 'caseLevelData': [{'biosampleId': 'HG00557', 'zygosity': {'label': '1/0', 'id': 'GENO:GENO_0000458'}}], 'identifiers': {'genomicHGVSId': '22:g.16050856G>T'}}

# %%
counts = len(list(dbname["genomicVariations"].find({"position.start": 16050855, "referenceBases": "G", "alternateBases": "T"})))

# %%
counts
# Out:
# 1

# %% [markdown]
# Searching non-existing variant

# %%
response = dbname["genomicVariations"].find({"position.start": 123, "referenceBases": "G", "alternateBases": "T"})

# %%
for r in response:
    print(r)

# %%
counts = len(list(dbname["genomicVariations"].find({"position.start": 123, "referenceBases": "G", "alternateBases": "T"})))

# %%
counts
# Out:
# 0

# %% [markdown]
# Region query

# %%
response = dbname["genomicVariations"].find({"position.start": {"$gte": 16050855}, "position.end": {"$lte":16050880 }})

# %%
for r in response:
    print(r)
# Out:
# {'_id': ObjectId('61f955fe7840ef8e91634f06'), 'variantType': 'SNP', 'position': {'end': [16050856], 'assemblyId': 'hs37', 'refseqId': '22', 'start': [16050855]}, 'variantInternalId': 'chr22_16050856_G_T', 'alternateBases': 'T', 'molecularAttributes': {'annotationImpact': ['MODIFIER'], 'molecularEffects': [{'id': 'ENSGLOSSARY:0000174', 'label': 'intergenic_region'}], 'geneIds': ['CHR_START-DUXAP8'], 'aminoacidChanges': ['.']}, 'referenceBases': 'G', 'caseLevelData': [{'biosampleId': 'HG00557', 'zygosity': {'label': '1/0', 'id': 'GENO:GENO_0000458'}}], 'identifiers': {'genomicHGVSId': '22:g.16050856G>T'}}
# {'_id': ObjectId('61f955fe7840ef8e91634f05'), 'alternateBases': 'T', 'molecularAttributes': {'molecularEffects': [{'id': 'ENSGLOSSARY:0000174', 'label': 'intergenic_region'}], 'geneIds': ['CHR_START-DUXAP8'], 'aminoacidChanges': ['.'], 'annotationImpact': ['MODIFIER']}, 'variantInternalId': 'chr22_16050874_G_T', 'position': {'assemblyId': 'hs37', 'refseqId': '22', 'end': [16050874], 'start': [16050873]}, 'variantType': 'SNP', 'identifiers': {'genomicHGVSId': '22:g.16050874G>T'}, 'caseLevelData': [{'biosampleId': 'HG03016', 'zygosity': {'label': '0/1', 'id': 'GENO:GENO_0000458'}}], 'referenceBases': 'G'}

# %%
counts = len(list(dbname["genomicVariations"].find({"position.start": {"$gte": 16050855}, "position.end": {"$lte":16050880 }})))

# %%
counts
# Out:
# 2

# %% [markdown]
# # Testing parse query

# %%
import re

# %%
query_dict = {
"ethnicity.id": "NCIT:C16352", 
"geographicOrigin.label": "England", 
"measures": 
    {"$elemMatch": 
        {"assayCode.label": "Weight",  
        "measurementValue.value": {"$gt": 90}} 
    }
}

# %%
request = "ethnicity=NCIT:C16352 geographicOrigin=England Weight>50 Height-standing>150"

# %%
request = "Weight=98.7828 Height-standing=187.4031"

# %%
request = "sampleOriginType=blood"

# %%
request_list = request.split(" ")

# %%
request_list
# Out:
# ['sampleOriginType=blood']

# %%
pattern = '(.+)([=|<|>])(.+)'

# %%
operator_dict = {
    "=": "$eq",
    ">": "$gt",
    "<": "$lt"
}

# %%
query_list_normal_obj = []

# %%
query_list_array_obj = []

# %%
for element in request_list:
    m = re.match(pattern, element, re.IGNORECASE)
    key = m.group(1)
    value = m.group(3)
    operator = m.group(2)
    print(key, value, operator)
    key_type = ".id" if ":" in value else ".label"
    try:
        value= float(value)
        str_operator = operator_dict[operator]
        query_measure = f"{{'measures': {{'$elemMatch': {{'assayCode{key_type}': '{key}',  'measurementValue.value': {{'{str_operator}': {value}}}}}}} }}"
        print(query_measure)
        query_list_array_obj.append(query_measure)
    except ValueError:
        query_normal = f"'{key}{key_type}': '{value}'"   
        print(query_normal)
        query_list_normal_obj.append(query_normal)
# Out:
# sampleOriginType blood =
# 'sampleOriginType.label': 'blood'

# %%
query_list_normal_obj
# Out:
# ["'sampleOriginType.label': 'blood'"]

# %%
query_list_array_obj
# Out:
# []

# %%
query_string_array_obj = ""
query_string_normal_obj = ""
if query_list_array_obj:
    query_string_array_obj = "'$and':[" +  ",".join(query_list_array_obj) + "]"
if query_list_normal_obj: 
    query_string_normal_obj = ",".join(query_list_normal_obj)

# %%
comma = "," if query_string_array_obj and query_string_normal_obj else ""
query_string = "{" + query_string_array_obj + comma + query_string_normal_obj + "}"

# %%
query_string
# Out:
# "{'sampleOriginType.label': 'blood'}"

# %%
query_string = query_string.replace("'", '"')

# %%
query_string
# Out:
# '{}'

# %%
query_json = json.loads(query_string)

# %%
query_json
# Out:
# {'$and': [{'measures': {'$elemMatch': {'assayCode.label': 'Weight',
#      'measurementValue.value': {'$eq': 98.7828}}}},
#   {'measures': {'$elemMatch': {'assayCode.label': 'Height-standing',
#      'measurementValue.value': {'$eq': 187.4031}}}}]}

# %%
results = dbname["individuals"].find(query_json)

# %%
results = dbname["biosamples"].find(query_json)

# %%
count = 0
for r in results:
    count+=1
    print(r)
# Out:
# {'_id': ObjectId('61f955f5d3ec3cdfd2b4adbc'), 'diseases': [{'diseaseCode': {'id': 'ICD10:D50', 'label': 'iron deficiency anaemia'}}], 'ethnicity': {'id': 'NCIT:C16352', 'label': 'Black or Black British'}, 'geographicOrigin': {'id': 'GAZ:00002641', 'label': 'England'}, 'id': 'NA20847', 'interventionsOrProcedures': [{'procedureCode': {'id': 'OPCS4:Z77.1', 'label': 'OPCS(v4-0.0):Condyle of tibia'}}], 'measures': [{'assayCode': {'id': 'LOINC:35925-4', 'label': 'BMI'}, 'date': '2021-09-24', 'measurementValue': {'units': {'id': 'NCIT:C49671', 'label': 'Kilogram per Square Meter'}, 'value': 28.12728351}}, {'assayCode': {'id': 'LOINC:3141-9', 'label': 'Weight'}, 'date': '2021-09-24', 'measurementValue': {'units': {'id': 'NCIT:C28252', 'label': 'Kilogram'}, 'value': 98.7828}}, {'assayCode': {'id': 'LOINC:8308-9', 'label': 'Height-standing'}, 'date': '2021-09-24', 'measurementValue': {'units': {'id': 'NCIT:C49668', 'label': 'Centimeter'}, 'value': 187.4031}}], 'sex': {'id': 'NCIT:C16576', 'label': 'female'}}

# %%
count
# Out:
# 1

# %% [markdown]
# # Improving parse query

# %%
INDIVIDUALS_DICT = {
    "diseases": "array_object_complex",
    "ethnicity": "object_id_label",
    "exposures": "array_object_complex",
    "geographicOrigin": "object_id_label",
    "id": "simple",
    "interventionsOrProcedures": "array_object_complex",
    "measures": "array_object_measures",
    "pedigrees": "array_object_complex",
    "phenotypicFeatures": "array_object_complex",
    "sex": "object_id_label",
    "treatments": "array_object_complex"
}

BIOSAMPLES_DICT = {
    "biosampleStatus": "object_id_label",
    "collectionDate": "simple",
    "collectionMoment": "simple",
    "diagnosticMarkers": "array_object_id_label",
    "histologicalDiagnosis": "object_id_label",
    "id": "simple",
    "individualId": "simple",
    "measurements": "array_object_measures",
    "obtentionProcedure": "object_complex",
    "pathologicalStage": "array_object_id_label",
    "pathologicalTnmFinding": "array_object_id_label",
    "phenotypicFeatures": "array_object_complex",
    "sampleOriginDetail": "object_id_label",
    "sampleOriginType": "object_id_label",
    "sampleProcessing": "object_id_label",
    "sampleStorage": "object_id_label",
    "tumorGrade": "object_id_label",
    "tumorProgression": "object_id_label",
}

# %%
set(INDIVIDUALS_DICT.values()) | set(BIOSAMPLES_DICT.values())
# Out:
# {'array_object_complex',
#  'array_object_id_label',
#  'array_object_measures',
#  'object_complex',
#  'object_id_label',
#  'simple'}

# %%
target_collection = "biosamples"
request = "sampleOriginType=blood"

# %%
target_collection = "biosamples"
request = "phenotypicFeatures.evidence.something=something"

# %%
target_collection = "individuals"
request = "Weight=98.7828 Height-standing=187.4031"

# %%
target_collection = "individuals"
request = "ethnicity=NCIT:C16352 geographicOrigin=England Weight>50 Height-standing>150"

# %%
target_collection = "individuals"
request = "individualId=HG00096"

# %%
def parse_query(request):

    request_list = request.split(" ")
    pattern = '(.+)([=|<|>])(.+)'
    operator_dict = {
        "=": "$eq",
        ">": "$gt",
        "<": "$lt"
    }
    query_list_normal_obj = []
    query_list_array_obj = []
    for element in request_list:
        m = re.match(pattern, element, re.IGNORECASE)
        key = m.group(1)
        value = m.group(3)
        operator = m.group(2)
        key_type = ".id" if ":" in value else ".label"
        try:
            value= float(value)
            str_operator = operator_dict[operator]
            query_measure = f"{{'measures': {{'$elemMatch': {{'assayCode{key_type}': '{key}',  'measurementValue.value': {{'{str_operator}': {value}}}}}}} }}"
            query_list_array_obj.append(query_measure)
        except ValueError:
            query_normal = f"'{key}{key_type}': '{value}'"   
            query_list_normal_obj.append(query_normal)

    query_string_array_obj = ""
    query_string_normal_obj = ""
    if query_list_array_obj:
        query_string_array_obj = "'$and':[" +  ",".join(query_list_array_obj) + "]"
    if query_list_normal_obj: 
        query_string_normal_obj = ",".join(query_list_normal_obj)

    comma = "," if query_string_array_obj and query_string_normal_obj else ""
    query_string = "{" + query_string_array_obj + comma + query_string_normal_obj + "}"

    query_string = query_string.replace("'", '"')
    query_json = json.loads(query_string)

    return query_json

# %%
def parse_query(request, schema):
    # separate key-value pairs
    request_list = request.split(" ")
    # info to identidy each key, operator and value
    pattern = '(.+)([=|<|>])(.+)'
    operator_dict = {
        "=": "$eq",
        ">": "$gt",
        "<": "$lt"
    }
    # loop through every key-value pair
    query_list_normal_obj = []
    query_list_array_obj = []
    for element in request_list:
        m = re.match(pattern, element, re.IGNORECASE)
        key = m.group(1)
        value = m.group(3)
        operator = m.group(2)
        
        # detect if value if string or ontology
        key_type = ".id" if ":" in value else ".label"  # useful if object_id_label
        
        # for this UI we assume if the value is float, the key is measurements
        try:
            value= float(value)
            str_operator = operator_dict[operator]
            query_measure = f"{{'measures': {{'$elemMatch': {{'assayCode{key_type}': '{key}',  'measurementValue.value': {{'{str_operator}': {value}}}}}}} }}"
            query_list_array_obj.append(query_measure)
        # if not, we can have object_id_label or simple 
        # NOTICE we ignore array_object_complex or array_object_id_label
        except ValueError:
            if key in schema and schema[key] == "object_id_label":
                query_normal = f"'{key}{key_type}': '{value}'"   
                query_list_normal_obj.append(query_normal)
            elif key in schema and schema[key] == "simple":
                query_normal = f"'{key}': '{value}'"   
                query_list_normal_obj.append(query_normal)
                
    # prepare query string            
    query_string_array_obj = ""
    query_string_normal_obj = ""
    if query_list_array_obj:
        query_string_array_obj = "'$and':[" +  ",".join(query_list_array_obj) + "]"
    if query_list_normal_obj: 
        query_string_normal_obj = ",".join(query_list_normal_obj)

    comma = "," if query_string_array_obj and query_string_normal_obj else ""
    query_string = ""
    query_string = "{" + query_string_array_obj + comma + query_string_normal_obj + "}"

    query_string = query_string.replace("'", '"')
    query_json = json.loads(query_string)

    return query_json

# %%
schema = INDIVIDUALS_DICT if target_collection == "individuals" else BIOSAMPLES_DICT

# %%
parse_query(request, schema)
# Out:
# {'$and': [{'measures': {'$elemMatch': {'assayCode.label': 'Weight',
#      'measurementValue.value': {'$gt': 50.0}}}},
#   {'measures': {'$elemMatch': {'assayCode.label': 'Height-standing',
#      'measurementValue.value': {'$gt': 150.0}}}}],
#  'ethnicity.id': 'NCIT:C16352',
#  'geographicOrigin.label': 'England'}

# %%
results = list(dbname[target_collection].find(parse_query(request, schema)))
len(results)
# Out:
# 20

# %%
results
# Out:
# [{'_id': ObjectId('61f955f7bb2ea315622cfde1'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_4',
#   'individualId': 'HG00100',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfde2'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_8',
#   'individualId': 'HG00105',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfde3'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_5',
#   'individualId': 'HG00101',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfde4'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_3',
#   'individualId': 'HG00099',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfde5'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_1',
#   'individualId': 'HG00096',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfde6'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_9',
#   'individualId': 'HG00106',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfde7'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_10',
#   'individualId': 'HG00107',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfde8'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_11',
#   'individualId': 'HG00108',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfde9'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_12',
#   'individualId': 'HG00109',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfdea'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_13',
#   'individualId': 'HG00110',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfdeb'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_16',
#   'individualId': 'HG00113',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfdec'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_14',
#   'individualId': 'HG00111',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfded'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_15',
#   'individualId': 'HG00112',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfdee'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_17',
#   'individualId': 'HG00114',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfdef'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_6',
#   'individualId': 'HG00102',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfdf0'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_7',
#   'individualId': 'HG00103',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfdf1'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_2',
#   'individualId': 'HG00097',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfdf2'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_21',
#   'individualId': 'HG00118',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfdf3'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_25',
#   'individualId': 'HG00122',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfdf4'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_20',
#   'individualId': 'HG00117',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfdf5'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_18',
#   'individualId': 'HG00115',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfdf6'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_23',
#   'individualId': 'HG00120',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfdf7'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_19',
#   'individualId': 'HG00116',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfdf8'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_24',
#   'individualId': 'HG00121',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfdf9'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_22',
#   'individualId': 'HG00119',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfdfa'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_27',
#   'individualId': 'HG00125',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfdfb'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_26',
#   'individualId': 'HG00123',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfdfc'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_28',
#   'individualId': 'HG00126',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfdfd'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_29',
#   'individualId': 'HG00127',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfdfe'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_30',
#   'individualId': 'HG00128',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfdff'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_33',
#   'individualId': 'HG00131',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe00'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_32',
#   'individualId': 'HG00130',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe01'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_31',
#   'individualId': 'HG00129',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe02'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_34',
#   'individualId': 'HG00132',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe03'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_35',
#   'individualId': 'HG00133',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe04'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_36',
#   'individualId': 'HG00136',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe05'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_39',
#   'individualId': 'HG00139',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe06'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_37',
#   'individualId': 'HG00137',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe07'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_44',
#   'individualId': 'HG00145',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe08'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_46',
#   'individualId': 'HG00148',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe09'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_43',
#   'individualId': 'HG00143',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe0a'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_45',
#   'individualId': 'HG00146',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe0b'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_42',
#   'individualId': 'HG00142',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe0c'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_38',
#   'individualId': 'HG00138',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe0d'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_48',
#   'individualId': 'HG00150',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe0e'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_50',
#   'individualId': 'HG00154',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe0f'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_49',
#   'individualId': 'HG00151',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe10'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_52',
#   'individualId': 'HG00157',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe11'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_51',
#   'individualId': 'HG00155',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe12'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_53',
#   'individualId': 'HG00158',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe13'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_55',
#   'individualId': 'HG00160',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe14'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_40',
#   'individualId': 'HG00140',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe15'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_54',
#   'individualId': 'HG00159',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe16'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_47',
#   'individualId': 'HG00149',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe17'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_56',
#   'individualId': 'HG00171',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe18'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_41',
#   'individualId': 'HG00141',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe19'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_57',
#   'individualId': 'HG00173',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe1a'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_58',
#   'individualId': 'HG00174',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe1b'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_64',
#   'individualId': 'HG00181',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe1c'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_65',
#   'individualId': 'HG00182',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe1d'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_63',
#   'individualId': 'HG00180',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe1e'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_59',
#   'individualId': 'HG00176',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe1f'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_68',
#   'individualId': 'HG00186',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe20'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_69',
#   'individualId': 'HG00187',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe21'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_67',
#   'individualId': 'HG00185',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe22'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_62',
#   'individualId': 'HG00179',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe23'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_60',
#   'individualId': 'HG00177',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe24'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_71',
#   'individualId': 'HG00189',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe25'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_70',
#   'individualId': 'HG00188',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe26'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_73',
#   'individualId': 'HG00231',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe27'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_66',
#   'individualId': 'HG00183',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe28'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_72',
#   'individualId': 'HG00190',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe29'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_74',
#   'individualId': 'HG00232',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe2a'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_61',
#   'individualId': 'HG00178',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe2b'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_76',
#   'individualId': 'HG00234',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe2c'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_77',
#   'individualId': 'HG00235',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe2d'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_82',
#   'individualId': 'HG00240',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe2e'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_78',
#   'individualId': 'HG00236',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe2f'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_83',
#   'individualId': 'HG00242',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe30'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_84',
#   'individualId': 'HG00243',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe31'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_85',
#   'individualId': 'HG00244',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe32'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_87',
#   'individualId': 'HG00246',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe33'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_88',
#   'individualId': 'HG00250',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe34'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_86',
#   'individualId': 'HG00245',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe35'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_75',
#   'individualId': 'HG00233',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe36'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_91',
#   'individualId': 'HG00253',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe37'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_81',
#   'individualId': 'HG00239',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe38'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_89',
#   'individualId': 'HG00251',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe39'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_90',
#   'individualId': 'HG00252',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe3a'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_93',
#   'individualId': 'HG00255',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe3b'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_95',
#   'individualId': 'HG00257',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe3c'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_97',
#   'individualId': 'HG00259',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe3d'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_92',
#   'individualId': 'HG00254',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe3e'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_96',
#   'individualId': 'HG00258',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe3f'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_94',
#   'individualId': 'HG00256',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe40'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_98',
#   'individualId': 'HG00260',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe41'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_79',
#   'individualId': 'HG00237',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe42'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_99',
#   'individualId': 'HG00261',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe43'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_80',
#   'individualId': 'HG00238',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe44'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_101',
#   'individualId': 'HG00263',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe45'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_102',
#   'individualId': 'HG00264',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe46'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_103',
#   'individualId': 'HG00265',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe47'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_108',
#   'individualId': 'HG00271',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe48'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_100',
#   'individualId': 'HG00262',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe49'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_105',
#   'individualId': 'HG00267',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe4a'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_109',
#   'individualId': 'HG00272',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe4b'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_110',
#   'individualId': 'HG00273',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe4c'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_111',
#   'individualId': 'HG00274',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe4d'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_112',
#   'individualId': 'HG00275',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe4e'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_115',
#   'individualId': 'HG00278',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe4f'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_113',
#   'individualId': 'HG00276',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe50'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_114',
#   'individualId': 'HG00277',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe51'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_104',
#   'individualId': 'HG00266',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe52'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_116',
#   'individualId': 'HG00280',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe53'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_117',
#   'individualId': 'HG00281',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe54'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_119',
#   'individualId': 'HG00284',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe55'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_120',
#   'individualId': 'HG00285',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe56'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_118',
#   'individualId': 'HG00282',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe57'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_121',
#   'individualId': 'HG00288',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe58'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_122',
#   'individualId': 'HG00290',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe59'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_106',
#   'individualId': 'HG00268',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe5a'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_124',
#   'individualId': 'HG00306',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe5b'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_123',
#   'individualId': 'HG00304',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe5c'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_125',
#   'individualId': 'HG00308',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe5d'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_107',
#   'individualId': 'HG00269',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe5e'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_127',
#   'individualId': 'HG00310',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe5f'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_126',
#   'individualId': 'HG00309',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe60'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_131',
#   'individualId': 'HG00318',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe61'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_129',
#   'individualId': 'HG00313',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe62'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_130',
#   'individualId': 'HG00315',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe63'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_134',
#   'individualId': 'HG00321',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe64'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_128',
#   'individualId': 'HG00311',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe65'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_133',
#   'individualId': 'HG00320',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe66'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_132',
#   'individualId': 'HG00319',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe67'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_135',
#   'individualId': 'HG00323',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe68'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_136',
#   'individualId': 'HG00324',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe69'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_137',
#   'individualId': 'HG00325',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe6a'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_141',
#   'individualId': 'HG00329',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe6b'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_140',
#   'individualId': 'HG00328',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe6c'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_142',
#   'individualId': 'HG00330',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe6d'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_144',
#   'individualId': 'HG00332',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe6e'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_139',
#   'individualId': 'HG00327',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe6f'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_146',
#   'individualId': 'HG00335',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe70'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_147',
#   'individualId': 'HG00336',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe71'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_148',
#   'individualId': 'HG00337',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe72'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_145',
#   'individualId': 'HG00334',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe73'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_150',
#   'individualId': 'HG00339',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe74'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_151',
#   'individualId': 'HG00341',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe75'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_152',
#   'individualId': 'HG00342',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe76'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_149',
#   'individualId': 'HG00338',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe77'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_153',
#   'individualId': 'HG00343',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe78'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_155',
#   'individualId': 'HG00345',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622cfe79'),
# ...
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_947',
#   'individualId': 'HG02462',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622d0197'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_953',
#   'individualId': 'HG02477',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622d0198'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_952',
#   'individualId': 'HG02476',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622d0199'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_954',
#   'individualId': 'HG02479',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622d019a'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_956',
#   'individualId': 'HG02484',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622d019b'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_955',
#   'individualId': 'HG02481',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622d019c'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_958',
#   'individualId': 'HG02489',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622d019d'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_957',
#   'individualId': 'HG02485',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622d019e'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_959',
#   'individualId': 'HG02490',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622d019f'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_960',
#   'individualId': 'HG02491',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622d01a0'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_962',
#   'individualId': 'HG02494',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622d01a1'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_961',
#   'individualId': 'HG02493',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622d01a2'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_963',
#   'individualId': 'HG02496',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622d01a3'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_964',
#   'individualId': 'HG02497',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622d01a4'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_965',
#   'individualId': 'HG02501',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622d01a5'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_967',
#   'individualId': 'HG02505',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622d01a6'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_968',
#   'individualId': 'HG02508',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622d01a7'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_966',
#   'individualId': 'HG02502',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622d01a8'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_948',
#   'individualId': 'HG02464',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622d01a9'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_969',
#   'individualId': 'HG02511',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622d01aa'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_972',
#   'individualId': 'HG02521',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622d01ab'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_970',
#   'individualId': 'HG02512',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622d01ac'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_971',
#   'individualId': 'HG02513',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622d01ad'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_975',
#   'individualId': 'HG02537',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622d01ae'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_974',
#   'individualId': 'HG02536',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622d01af'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_973',
#   'individualId': 'HG02522',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622d01b0'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_976',
#   'individualId': 'HG02541',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622d01b1'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_978',
#   'individualId': 'HG02546',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622d01b2'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_981',
#   'individualId': 'HG02555',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622d01b3'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_985',
#   'individualId': 'HG02562',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622d01b4'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_980',
#   'individualId': 'HG02554',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622d01b5'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_983',
#   'individualId': 'HG02558',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622d01b6'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_979',
#   'individualId': 'HG02549',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622d01b7'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_986',
#   'individualId': 'HG02568',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622d01b8'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_987',
#   'individualId': 'HG02570',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622d01b9'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_988',
#   'individualId': 'HG02571',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622d01ba'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_982',
#   'individualId': 'HG02557',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622d01bb'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_990',
#   'individualId': 'HG02574',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622d01bc'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_989',
#   'individualId': 'HG02573',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622d01bd'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_993',
#   'individualId': 'HG02582',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622d01be'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_992',
#   'individualId': 'HG02580',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622d01bf'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_991',
#   'individualId': 'HG02577',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622d01c0'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_995',
#   'individualId': 'HG02585',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622d01c1'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_996',
#   'individualId': 'HG02586',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622d01c2'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_994',
#   'individualId': 'HG02583',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622d01c3'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_997',
#   'individualId': 'HG02588',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622d01c4'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_998',
#   'individualId': 'HG02589',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622d01c5'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_999',
#   'individualId': 'HG02594',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622d01c6'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_977',
#   'individualId': 'HG02545',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622d01c7'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_1000',
#   'individualId': 'HG02595',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  {'_id': ObjectId('61f955f7bb2ea315622d01c8'),
#   'biosampleStatus': {'id': 'EFO:0009654', 'label': 'reference sample'},
#   'collectionDate': '2020-09-11',
#   'collectionMoment': 'P40Y1M1D',
#   'id': 'synthetic_sample_1002',
#   'individualId': 'HG02600',
#   'sampleOriginType': {'id': 'UBERON:0000178', 'label': 'blood'}},
#  ...]
